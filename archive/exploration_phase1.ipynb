# %% [markdown]
# # Exploration Notebook
# Ad-hoc analysis for acoustic space classification. This notebook is intentionally outside the reproducible pipeline.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('../data/processed/features.csv')
df.head()
# Out:
#       rt60       c80       d50        ts                            room_id  \
# 0  2.54725  4.782961  0.629191  0.057931  Hotel_SkalskyDvur_ConferenceRoom2
# 1  2.90325  2.143138  0.448857  0.083704  Hotel_SkalskyDvur_ConferenceRoom2
# 2  2.74825  5.442212  0.634361  0.057808  Hotel_SkalskyDvur_ConferenceRoom2
# 3  2.74425  6.288686  0.705516  0.049863  Hotel_SkalskyDvur_ConferenceRoom2
# 4  2.72675  4.452554  0.581695  0.068896  Hotel_SkalskyDvur_ConferenceRoom2
#
#                                                 path            label
# 0  data/raw/BUT_ReverbDB_rel_19_06_RIR-Only/Hotel...  conference_room
# 1  data/raw/BUT_ReverbDB_rel_19_06_RIR-Only/Hotel...  conference_room
# 2  data/raw/BUT_ReverbDB_rel_19_06_RIR-Only/Hotel...  conference_room
# 3  data/raw/BUT_ReverbDB_rel_19_06_RIR-Only/Hotel...  conference_room
# 4  data/raw/BUT_ReverbDB_rel_19_06_RIR-Only/Hotel...  conference_room

# %%
feature_cols = ['rt60', 'c80', 'd50', 'ts']
sns.pairplot(df[feature_cols + ['label']], hue='label', corner=True)
plt.show()
